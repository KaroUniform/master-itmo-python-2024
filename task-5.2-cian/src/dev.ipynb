# %% [markdown]
# ## В этом файле отображен ход работы над заданием 5_2
# ### Здесь отображены отдельные артефакты и фрагменты кода, послужившие основой для main.py

# %%
url = "https://www.cian.ru/cat.php?deal_type=rent&engine_version=2&offer_type=flat&p=2&region=1&room1=1&room2=1&room3=1&room4=1&room5=1&room6=1&room7=1&room9=1&type=4"

# %%
headers = {
        "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9",
        "user-agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.106 Safari/537.36"
    }

# %%
from bs4 import BeautifulSoup
import httpx

content = None

async def fetch_page(url):
    
    global content
    async with httpx.AsyncClient() as client:
        response = await client.get(url, headers=headers)
        if response.status_code == 200:
            content = response.text
        else:
            print(f"Ошибка получения страницы: {response.status_code}")

await fetch_page(url)

# %%
soup = BeautifulSoup(content, 'html')
links = soup.find_all(class_= '_93444fe79c--link--eoxce')

# %%
links = list(set([link['href'] for link in links]))

# %%
async def download_page(client: httpx.AsyncClient, url: str, data:list):
    response = await client.get(url, headers=headers)
    if response.status_code == 200:
        data.append(response.text)
    else:
        print(f"Ошибка получения страницы: {response.status_code}")
    return content

async def download_pages(links, data):
    """
    Asynchronously downloads a specified number of images to a given directory.
    
    Args:
    - num_images: Number of images to download.
    - output_dir: Directory to save the downloaded images.
    """
    async with httpx.AsyncClient() as session:
        tasks = [
            download_page(session, link, data)
            for link in links
        ]
        await asyncio.gather(*tasks)

# %% [markdown]
# ### Обычно ожидания 3 секунд хватает. Оптимальным вариантом будет подключение прокси

# %%
import asyncio

# %%
data = []
for pair in zip(links[::2], links[1::2]):
    await download_pages(pair, data)
    await asyncio.sleep(3)
# Out:
# Ошибка получения страницы: 429
# Ошибка получения страницы: 429
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[63], line 4
#       2 for pair in zip(links[::2], links[1::2]):
#       3     await download_pages(pair, data)
# ----> 4     await asyncio.sleep(5)
#
# File ~/miniconda3/envs/itmo-ab/lib/python3.12/asyncio/tasks.py:665, in sleep(delay, result)
#     661 h = loop.call_later(delay,
#     662                     futures._set_result_unless_cancelled,
#     663                     future, result)
#     664 try:
# --> 665     return await future
#     666 finally:
#     667     h.cancel()
#
# CancelledError:

# %%
def get_flat_info(soup: BeautifulSoup):
    offer_summary_info_group = soup.find('div', {'data-name': 'OfferSummaryInfoGroup'})
    apartment_info = {}
    items = offer_summary_info_group.find_all('div', {'data-name': 'OfferSummaryInfoItem'})
    for item in items:
        key = item.find('p', class_='a10a3f92e9--color_gray60_100--mYFjS').text.strip()
        value = item.find('p', class_='a10a3f92e9--color_black_100--Ephi7').text.strip()
        apartment_info[key] = value

    return apartment_info

# %%
def get_building_info(soup: BeautifulSoup):
    house_info_group = soup.find('div', {'class': 'a10a3f92e9--group--K5ZqN', 'class': 'a10a3f92e9--right--_9uBM'})
    house_info = {}
    items = house_info_group.find_all('div', {'data-name': 'OfferSummaryInfoItem'})
    for item in items:
        key_element = item.find('p', class_='a10a3f92e9--color_gray60_100--mYFjS')
        value_element = item.find('p', class_='a10a3f92e9--color_black_100--Ephi7')
        if key_element and value_element:
            key = key_element.text.strip()
            value = value_element.text.strip()
            house_info[key] = value
    
    return house_info

# %%
def get_goods(soup: BeautifulSoup):
    features_layout = soup.find('div', {'data-name': 'FeaturesLayout'})
    amenities_list = []
    items = features_layout.find_all('div', {'data-name': 'FeaturesItem'})
    for item in items:
        amenity = item.text.strip()
        amenities_list.append(amenity)

    return(amenities_list)

# %%
from data import FlatData

# %%
len(data)
# Out:
# 11

# %%
ready_data = []
for link, d in zip(links[:9], data[:9]):
    soup = BeautifulSoup(d, 'html.parser')
    title = soup.find('h1', class_='a10a3f92e9--title--vlZwT').text
    price = soup.find('div', class_='a10a3f92e9--amount--ON6i1').find('span').text
    attributes = {}
    fact_items = soup.find_all('div', class_='a10a3f92e9--item--iWTsg')
    for item in fact_items:
        attribute_span = item.find('span', class_='a10a3f92e9--color_black_100--Ephi7')
        if attribute_span:
            attribute = attribute_span.text.strip()
            value_span = attribute_span.find_next_sibling('span')
            if value_span:
                value = value_span.text.strip()
            else:
                value = ''
            attributes[attribute] = value
    description = soup.find('div', class_='a10a3f92e9--layout--BaqYw').text.strip()
    flat_ifno = get_flat_info(soup)
    building_info = get_building_info(soup)
    goods = get_goods(soup)
    ready_data.append(FlatData(link=link, name=title, price=price, description=description, other_description=attributes, about_flat=flat_ifno, about_building=building_info, goods=goods))

# %%
ready_data
# Out:
# [FlatData(link='https://www.cian.ru/rent/flat/278216280/', name='5-комн. квартира, 240 м²', price='600\xa0000\xa0₽/мес.', description='Без комиссии для арендатора!  С коллегами работаем 50/50  Лот  38596. Предлагается потрясающая двухуровневая 5-ти комнатная квартира в ЖК "Континенталь". \nПланировка первого уровня: кухня-гостиная, 2 спальни, 2 санузла, гардеробная комната, лоджия.\nПланировка второго уровня: спальня, кабинет (спальня), гардеробная комната, санузел.\nЭксклюзивный дизайнерский ремонт, мебель и техника от ведущих производителей Италии. Потолки 3,20 м. Презентабельная входная группа в доме. Есть подземная и наземная парковка.\nОперативный показ!', other_description={'Оплата ЖКХ': 'включена (без счётчиков)', 'Залог': '600 000 ₽', 'Комиссии': 'нет', 'Предоплата': '1 месяц', 'Срок аренды': 'от года', 'Торг': 'возможен', 'Условия проживания': 'можно с детьми и животными'}, about_flat={'Общая площадь': '240', 'Жилая площадь': '155', 'Площадь кухни': '30', 'Высота потолков': '3,3\xa0м', 'Санузел': '3 раздельных', 'Ремонт': 'Дизайнерский'}, about_building={'Год постройки': '2011', 'Мусоропровод': 'Да', 'Тип дома': 'Монолитный', 'Тип перекрытий': 'Железобетонные', 'Подъезды': '2', 'Отопление': 'Центральное', 'Аварийность': 'Нет'}, goods=['Холодильник', 'Посудомоечная машина', 'Стиральная машина', 'Кондиционер', 'Телевизор', 'Интернет', 'Ванна', 'Душевая кабина', 'Мебель на кухне', 'Мебель в комнатах']),
#  FlatData(link='https://www.cian.ru/rent/flat/291438149/', name='2-комн. апартаменты, 90 м²', price='1\xa0000\xa0000\xa0₽/мес.', description='2-комн. апартаменты, 90 м² \nПОДЗЕМНАЯ ПАРКОВКА И УБОРКА РЕЗИДЕНЦИЙ ВКЛЮЧЕНЫ. \nГости апартаментов могут воспользоваться доступом на специальных условиях в спа отеля Four Seasons Hotel Moscow и возможностью круглосуточного обслуживания апартаментов по меню рум-сервис отеля класса люкс.\n\nВашему вниманию предлагаются сервисные апартаменты в аренду в нескольких шагах от Кремля и Красной площади. Изысканная полностью меблированная резиденция с одной спальней и гостиной, площадью 90 кв.м. \nПланировка резиденции предусматривает объединённую гостиную и обеденную зону с полноразмерной кухней. Кухня оборудована немецкой встроенной техникой Kppersbusch и укомплектована полным набором посуды. Спальня с большой двуспальной кроватью (king size) и удобной рабочей зоной. Две гардеробные комнаты, два санузла и подсобное помещение со стиральной и сушильной машинами Miele. \n\nВ стоимость проживания в комплексе Резиденции Москва включены следующие услуги: \n- 1 машиноместо на охраняемом подземном паркинге; \n- услуги ресепшн 24/7;\n- консьерж-сервис; \n- дважды в неделю: влажная уборка с заменой постельного белья;\n- ежедневно: вынос мусора, легкая поддерживающая уборка,\n пополнение бумажных и косметических средств;\n- служба безопасности 24/7. \n\nВ комплектацию резиденции включены следующие удобства: \n\n- предметы мебели в стиле неоклассики;\n- полностью оборудованная кухня: плита, духовой шкаф, посудомоечная машина, микроволновая печь, холодильник, кофемашина Nespresso, чайник, посуда, бокалы и столовые приборы;\n- стиральная и сушильная машины Miele; \n- утюг и гладильная доска; \n- махровые халаты, тапочки, фен, косметические средства Acqua di Parma;\n- постельное белье премиального качества; \n- интерактивное телевидение; \n- высокоскоростной Интернет / Wi-Fi; \n- электронные замки и система контроля доступа; \n- мини-сейф в каждой мастер-спальне;\n- телефон;\n- система умный дом;\n- фильтрация воды.\n\nВид из окон - Во внутренний дворик', other_description={'Оплата ЖКХ': 'включена (без счётчиков)', 'Залог': '1 000 000 ₽', 'Комиссии': 'нет', 'Предоплата': '1 месяц', 'Срок аренды': 'от года', 'Условия проживания': 'можно с детьми и животными'}, about_flat={'Тип жилья': 'Апартаменты', 'Общая площадь': '90', 'Санузел': '1 совмещенный, 1 раздельный', 'Вид из окон': 'Во двор', 'Ремонт': 'Дизайнерский'}, about_building={'Год постройки': '2015', 'Количество лифтов': '1 пассажирский', 'Тип дома': 'Монолитный', 'Тип перекрытий': 'Нет информации', 'Отопление': 'Нет информации', 'Аварийность': 'Нет'}, goods=['Холодильник', 'Посудомоечная машина', 'Стиральная машина', 'Кондиционер', 'Телевизор', 'Интернет', 'Ванна', 'Душевая кабина', 'Мебель на кухне', 'Мебель в комнатах']),
#  FlatData(link='https://www.cian.ru/rent/flat/300444961/', name='2-комн. квартира, 45,7 м²', price='52\xa0600\xa0₽/мес.', description='Квартира сдаётся через сервис "ПИК-Аренда"  её можно посмотреть когда Вам удобно: бронируете время, забираете ключи или встречаетесь с нашим представителем и спокойно осматриваете. Если всё понравится, договор подпишем онлайн и будем поддерживать Вас на всех этапах аренды.\n\nСдаётся уютная 2-комнатная квартира с хорошим ремонтом, балконом и совмещённым санузлом, без депозита! Квартира оборудована всей необходимой для проживания мебелью и техникой: есть кухонный гарнитур, плита, посудомоечная машина, телевизор, стиральная машина, холодильник. Можно обсудить покупку дополнительной мебели/техники в счёт арендной платы. Проведён интернет с Wi-Fi и подключено кабельное/цифровое ТВ. Полы - плитка и ламинат. Окна выходят во двор, на запад. Есть бесплатная парковка.\n\nСобственник готов заселить не более 2 взрослых жильцов с детьми или заключить договор с юридическим лицом. С домашним питомцем нельзя.\n\nДом находится в районе с развитой инфраструктурой: в пешей доступности находятся продуктовые супермаркеты, школы, детские сады, медицинские учреждения, аптеки, кафе, салоны красоты. Недалеко расположены Гольяновский пруд и Гольяновский парк.\n\nДо м. Щёлковская - 14 минут пешком. \n\nДом включен в программу реновации (расселение планируется с 2025 по 2028 г.г.)', other_description={'Оплата ЖКХ': 'включена (без счётчиков)', 'Залог': 'нет', 'Комиссия': '40%', 'Предоплата': '1 месяц', 'Срок аренды': 'от года', 'Условия проживания': 'можно с детьми'}, about_flat={'Общая площадь': '45,7', 'Жилая площадь': '30', 'Площадь кухни': '6', 'Высота потолков': '2,7\xa0м', 'Планировка': 'Изолированная', 'Санузел': '1 совмещенный', 'Балкон/лоджия': '1 балкон', 'Вид из окон': 'Во двор', 'Ремонт': 'Косметический'}, about_building={'Год постройки': '1959', 'Строительная серия': '1-510', 'Тип дома': 'Блочный', 'Тип перекрытий': 'Железобетонные', 'Подъезды': '4', 'Отопление': 'Центральное', 'Аварийность': 'Нет', 'Газоснабжение': 'Центральное'}, goods=['Холодильник', 'Посудомоечная машина', 'Стиральная машина', 'Телевизор', 'Интернет', 'Ванна', 'Мебель на кухне', 'Мебель в комнатах']),
#  FlatData(link='https://www.cian.ru/rent/flat/300323204/', name='2-комн. квартира, 45 м²', price='75\xa0000\xa0₽/мес.', description='Вашему вниманию предлагается двухкомнатная квартира, с двумя изолированными комнатами, кухня просторная. Сделан хороший качественный ремонт. Кухня встроенная, вся бытовая техника, кондиционер. Полностью меблированна. При желании мебель можно вывезти. Санузел совмещенный (ванна). Застекленный балкон. Домофон, квартира под охраной. Стихийная парковка. Развитая инфраструктура, рядом с домом абсолютно все, особенность района Делегатский парк. До метро пешая доступность. \n\nАрт. 28581419', other_description={'Оплата ЖКХ': 'включена (без счётчиков)', 'Залог': '75 000 ₽', 'Комиссия': '50%', 'Предоплата': '1 месяц', 'Срок аренды': 'от года', 'Торг': 'возможен', 'Условия проживания': 'можно с детьми'}, about_flat={'Общая площадь': '45', 'Жилая площадь': '30', 'Площадь кухни': '9', 'Планировка': 'Изолированная', 'Санузел': '1 совмещенный', 'Балкон/лоджия': '1 балкон', 'Вид из окон': 'Во двор', 'Ремонт': 'Евроремонт'}, about_building={'Год постройки': '1962', 'Строительная серия': 'Индивидуальный проект', 'Количество лифтов': '1 пассажирский', 'Тип перекрытий': 'Нет информации', 'Парковка': 'Наземная', 'Подъезды': '1', 'Отопление': 'Центральное', 'Аварийность': 'Нет', 'Газоснабжение': 'Центральное'}, goods=['Холодильник', 'Стиральная машина', 'Кондиционер', 'Телевизор', 'Интернет', 'Мебель на кухне', 'Мебель в комнатах']),
#  FlatData(link='https://www.cian.ru/rent/flat/300425222/', name='2-комн. квартира, 45 м²', price='52\xa0000\xa0₽/мес.', description='Мы на связи и будем рады вам помочь! \n\n- Фотографии соответствуют данному объекту! \n- Организуем МАКСИМАЛЬНО оперативный показ! \n- Договор аренды заключается ИСКЛЮЧИТЕЛЬНО с собственником жилья!\n\nОтличный объект недвижимости для комфортной жизни! \nВ квартире есть всё необходимое!\n\nРазвитая инфраструктура! Хотя где она в Москве не развитая?=)\n\nСобачка, кошечка, хомячок или крокодильчик обсуждаются индивидуально! \n\nДети - цветы жизни - так же обсуждаются индивидуально!\n\nПри взаимной симпатии залог можно разбить на два месяца!\n\nУ собственника могут быть дополнительные пожелания к жильцам!', other_description={'Оплата ЖКХ': 'включена (без счётчиков)', 'Залог': '52 000 ₽', 'Комиссия': '50%', 'Предоплата': '1 месяц', 'Срок аренды': 'от года', 'Условия проживания': 'можно с детьми и животными'}, about_flat={'Общая площадь': '45', 'Жилая площадь': '30', 'Площадь кухни': '5', 'Высота потолков': '2,7\xa0м', 'Планировка': 'Изолированная', 'Санузел': '1 раздельный', 'Балкон/лоджия': '1 балкон', 'Вид из окон': 'Во двор', 'Ремонт': 'Евроремонт'}, about_building={'Год постройки': '2005', 'Строительная серия': '111-М', 'Количество лифтов': '1 пассажирский, 1 грузовой', 'Тип дома': 'Монолитный', 'Тип перекрытий': 'Железобетонные', 'Парковка': 'Наземная', 'Подъезды': '3', 'Отопление': 'Центральное', 'Аварийность': 'Нет'}, goods=['Холодильник', 'Стиральная машина', 'Телевизор', 'Интернет', 'Ванна', 'Мебель на кухне', 'Мебель в комнатах']),
#  FlatData(link='https://www.cian.ru/rent/flat/295380184/', name='Апартаменты-студия, 32 м²', price='от\xa06\xa0990\xa0₽/сут.', description='БРОНИРУЙ АПРЕЛЬ СО СКИДКОЙ 10% ПО ПРОМОКОДУ ВЕСНА10*\nДизайнерские апартаменты на 13 этаже ЖК Лайнер!\nПанорамный балкон с видом на город! Идеальное место для отдыха! \n\nМетро ЦСКА 1 минута пешком.\nВысокий Рейтинг в сервисах бронирования. Забронируйте прямо сейчас! \n\nПрестижный район Москвы! ЖК располагается всего в 1 минуте от современного парка и крупнейшего ТРЦ в Европе.\n\nВ квартире есть все необходимое для проживания 3-х человек:\n- ортопедическая двуспальная кровать;\n- новый ортопедический матрас;\n- кресло-кровать;\n- вместительный шкаф;\n- кондиционер; \n- большой Smart TV, Wi-Fi;\n- гладильная доска, утюг, сушилка;\n- постельное белье, комплект полотенец, тапочки;\n- халаты (по запросу).\n\nКухня: \n- плита, духовка, микроволновка, вытяжка, чайник, кофемашина, холодильник;\n- набор посуды и вся необходимая утварь,\n- чай, кофе, соль, сахар.\n\nВанная комната: \n- ванная, стиральная машина, фен;\n- одноразовые: гель для душа, шампунь, мыло.\n\nИнфраструктура: \n- ТРЦ Авиапарк;\n- Парк Ходынское поле с прудом, спортивными и детскими площадками;\n- ЛД Мегаспорт СК ЦСКА и Стадион Динамо;\n- Концертный зал Adrenaline Stadium и Киношкола;\n- Фитнес-клуб и Спа-салон и бассейн;\n- Барбершоп и Кальян-бар;\n- Мед. лаборатория, стоматология, диагностический центр;\n- Автомойка и шиномонтаж;\n- Белорусский вокзал (10 мин на авто);\n- Москва Сити (11 мин на метро);\n- Красная площадь (21 мин на метро до ст. Театральная, Площадь Революции, Охотный ряд);\n- Аэропорт Шереметьево (30 мин на авто).\n\nПравила проживания:\n- заезд  с 15:00;\n- выезд  до 11:00;\n- заселение бесконтактное 24/7;\n- от 22 лет при наличии паспорта; \n- при заселении от 2 чел. старшему гостью должно быть не менее 25 лет;\n- заселение в возрасте от 18 до 22 лет только по согласованию с менеджером и не более 2 чел.;\n- разрешено проживание с детьми от 12 лет. Заселение в возрасте до 18 лет только при проживании с родителями с документальным подтверждением родства;\n- курение и шумные мероприятия в квартире не допускаются;\n- проживание с животными запрещено;\n- выставляем счета организациям и предоставляем документы без доп. оплаты;\n- принимаем оплату через эквайринг;\n- оформление регистрации за доп. плату 10 000 руб/чел.\n- страховой депозит за сохранность имущества в размере 7000 руб. Возвращается после уборки в день выезда. \n- при бронировании вносится доп. сбор за клининг  1000 руб;\n- при позднем заезде с 23:00 до 9:00 вносится доп. сбор - 500 руб.\n\nЦена указана на проживание 2 человек в будни.\nДоплата за 3-го человека:\n- 500 руб/чел. в будние дни;\n- 1000 руб/чел. в праздничные дни.\nЦена может варьироваться в зависимости от дня недели и количества человек.\nВ праздники, выходные дни, а также аренда для проведения съемок выше - уточняйте у оператора.\n\nЖдем наших дорогих гостей!\n*Скидка предоставляется при 100% предоплате и является невозвратной.', other_description={'Залог': '7 000 ₽', 'Условия проживания': 'можно с детьми'}, about_flat={'Тип жилья': 'Апартаменты', 'Общая площадь': '32', 'Площадь кухни': '10', 'Санузел': '1 совмещенный', 'Балкон/лоджия': '1 балкон', 'Вид из окон': 'На улицу', 'Спальных мест': '3', 'Ремонт': 'Косметический'}, about_building={'Год постройки': '2016', 'Количество лифтов': '1 пассажирский', 'Тип дома': 'Монолитный', 'Тип перекрытий': 'Нет информации', 'Парковка': 'Наземная', 'Отопление': 'Нет информации', 'Аварийность': 'Нет'}, goods=['Холодильник', 'Стиральная машина', 'Кондиционер', 'Телевизор', 'Интернет', 'Ванна', 'Мебель на кухне', 'Мебель в комнатах']),
#  FlatData(link='https://www.cian.ru/rent/flat/300402154/', name='3-комн. квартира, 127 м²', price='400\xa0000\xa0₽/мес.', description='Лот 104499. Татьяна Белогусева.\n\nЖК Смоленская застава. Чудесная 3-комнатная квартира в новом современном доме. 11 / 16 этаж. Спален: 2, санузлов: 2. Общая площадь: 127 кв.м. Потолки 3.2 м. Ремонт в современном стиле. Квартира полностью с мебелью, вывоз обсуждается. Огороженная, охраняемая территория. Подземный паркинг, 2 машиноместа входят в стоимость. Окна в тихий двор. Есть балкон.  В наличии: посудомоечная машина, холодильник, кондиционер, душевая кабина, стиральная машина, подогрев полов. Коммунальные платежи, в том числе и счетчики входят в стоимость. Телевизор, высокоскоростной интернет. Можно с детьми.\n\nБез комиссии для арендатора.\n\nБонус агенту 50%.\n\nЕсть презентации в pdf на русском или английском для партнеров.', other_description={'Оплата ЖКХ': 'включена (без счётчиков)', 'Залог': '400 000 ₽', 'Комиссии': 'нет', 'Предоплата': '1 месяц', 'Срок аренды': 'от года', 'Торг': 'возможен', 'Условия проживания': 'можно с детьми'}, about_flat={'Общая площадь': '127', 'Жилая площадь': '50', 'Площадь кухни': '16', 'Высота потолков': '3,2\xa0м', 'Санузел': '2 совмещенных', 'Балкон/лоджия': '1 балкон', 'Вид из окон': 'Во двор', 'Ремонт': 'Евроремонт'}, about_building={'Год постройки': '2008', 'Мусоропровод': 'Нет', 'Количество лифтов': '2 пассажирских, 1 грузовой', 'Тип дома': 'Монолитный', 'Тип перекрытий': 'Железобетонные', 'Парковка': 'Подземная', 'Подъезды': '9', 'Отопление': 'Центральное', 'Аварийность': 'Нет'}, goods=['Холодильник', 'Посудомоечная машина', 'Стиральная машина', 'Кондиционер', 'Телевизор', 'Интернет', 'Душевая кабина', 'Мебель на кухне', 'Мебель в комнатах']),
#  FlatData(link='https://www.cian.ru/rent/flat/300018498/', name='Многокомнатная квартира, 235 м²', price='2\xa0000\xa0000\xa0₽/мес.', description='ID 46054:  Эксклюзивное предложение, абсолютно новая видовая квартира с 5 спальнями на высоком этаже в новом элитном ЖК "На Тишинке". В квартире только что закончен ремонт, она полностью меблирована и оснащена всей необходимой для комфортной жизни бытовой техникой.  Общая площадь квартиры 235м2, планировка: кухня с островом, гостиная-столовая с лоджией, 5 спален, кабинет с комнатой хранения, 4 полных санузла, много мест для хранения вещей (гардеробная и шкафы), постирочная со стиральной и сушильной машинами и сушильным шкафом. Ремонт в легком современном стиле с использованием натуральных материалов, итальянская мебель, много света. Отличные виды на центр Москвы из каждого окна. В стоимость аренды входит использование 2 парковочных мест в подземном гараже. ЖК "На Тишинке" это презентабельная входная группа, круглосуточный консьерж-сервис, служба охраны, гостиная с камином для приватных встреч, библиотека для переговоров, приватный (только для жильцов) фитнес-клуб с 25-метровым бассейном, детский сад на 80 мест со спортивной и игровой зонами, двухуровневый подземный паркинг, зеленая зона отдыха внутри двора, онлайн контроль инженерных систем, регулярная уборка территории и холлов. Тихий и уютный Пресненский район, в котором расположен комплекс "На Тишинке", отличается однородным социальным окружением и развитой инфраструктурой:4 станции метро в пешей доступности, легкий выезд на Тверскую, Садовое и ТТК, 10 минут до Сити, магазины, рестораны и театры, рядом высокорейтинговые школы.    \n\nБез комиссии для арендаторов\nРаботаем с партнерами\nДействуем в интересах клиентов.\n\nPlease feel free to contact Intermark Real Estate to get detailed information or to set up a viewing! 24/7 help desk service with English-speaking operators\n        \nВ квартире: Полностью меблированная, М/место в подземном паркинге, Бассейн, Посудомоечная машина, Стиральная машина, Бойлер, Душевая кабина, Теплые полы, Спутниковое/кабельное телевидение, Тренажерный зал, Видеонаблюдение, Охрана, Интернет, Балкон, Видовая квартира, Изолированная кухня, Европланировка, Интерьер в современном стиле, Сплит-система, Гардеробная, Лифт, Spa комплекс, Лоджия, Мебель в комнатах, Телефон, Телевизор, Мебель на кухне, Окна на улицу, Окна во двор', other_description={'Оплата ЖКХ': 'включена (без счётчиков)', 'Залог': '2 000 000 ₽', 'Комиссии': 'нет', 'Предоплата': '1 месяц', 'Срок аренды': 'от года', 'Условия проживания': 'можно с детьми'}, about_flat={'Общая площадь': '235', 'Жилая площадь': '158', 'Площадь кухни': '14', 'Высота потолков': '3,5\xa0м', 'Планировка': 'Смежная/Изолированная', 'Санузел': '4 совмещенных', 'Балкон/лоджия': '1 лоджия, 1 балкон', 'Вид из окон': 'На улицу и двор', 'Ремонт': 'Дизайнерский'}, about_building={'Год постройки': '2021', 'Строительная серия': 'Индивидуальный проект', 'Количество лифтов': '1 пассажирский', 'Тип перекрытий': 'Нет информации', 'Парковка': 'Подземная', 'Подъезды': '3', 'Отопление': 'Нет информации', 'Аварийность': 'Нет'}, goods=['Холодильник', 'Посудомоечная машина', 'Стиральная машина', 'Кондиционер', 'Телевизор', 'Интернет', 'Ванна', 'Душевая кабина', 'Мебель на кухне', 'Мебель в комнатах'])]

# %%
import json

# %%
json_data = [flat.dict() for flat in ready_data]

# Записываем JSON на диск
with open('flats_data.json', 'w', encoding="utf-8") as json_file:
    json.dump(json_data, json_file, indent=4, ensure_ascii=False)
print("Data has been written to flats_data.json")
# Out:
# Data has been written to flats_data.json
